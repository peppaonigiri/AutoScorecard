# %%
import bcrypt

password = "root"
hashed = bcrypt.hashpw(password.encode("utf-8"), bcrypt.gensalt()).decode("utf-8")
print(hashed)
# Out:
# $2b$12$lBcpsTbLsjwAGjqQPF1OM.zDgU5fE1fVHXmMzEdTP2uzstnS.nPTS
